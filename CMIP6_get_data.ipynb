# %% [markdown]
# <a href="https://colab.research.google.com/github/benmsanderson/prpattern/blob/main/CMIP6_get_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 4xCO2 read data
#
#
# CMIP6

# %%
readdata=1
authdrive=1

# %% [markdown]
# Desired interpolation grid

# %% [markdown]
# Desired experiments

# %%
flds=['tas','rsut','rlut','rsdt']
expts=['1pctCO2','abrupt-4xCO2','piControl','historical','ssp126','ssp585']
calstrt=[True,True,True,False,False,False]
dbe=['CMIP','CMIP','CMIP','CMIP','ScenarioMIP','ScenarioMIP']

# %% [markdown]
# Install some stuff

# %%
# !pip uninstall -y albumentations >/dev/null
# !pip install --upgrade xarray zarr gcsfs cftime pydsm nc-time-axis imgaug matplotlib==3.1.3 progress eofs cartopy netcdf4 >/dev/null
# Out:
# WARNING: Discarding https://files.pythonhosted.org/packages/f6/55/1e1c737dc9436b320deead73d1c455ddbb74b8b6992081863492f6f6378a/Cartopy-0.20.2.tar.gz#sha256=4d08c198ecaa50a6a6b109d0f14c070e813defc046a83ac5d7ab494f85599e35 (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpqor15lb8 Check the logs for full command output.
# WARNING: Discarding https://files.pythonhosted.org/packages/fc/59/aa52698e3838f4cd0e7eaa75bd86837e9e0b05041dbdaee3cda2fffced06/Cartopy-0.20.1.tar.gz#sha256=91f87b130e2574547a20cd634498df97d797abd12dcfd0235bc0cdbcec8b05e3 (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpo73q0mas Check the logs for full command output.
# WARNING: Discarding https://files.pythonhosted.org/packages/0f/c0/58453b036e79046d211f083880d58dcce787e7e07647ac25dc46c6555099/Cartopy-0.20.0.tar.gz#sha256=eae58aff26806e63cf115b2bce9477cedc4aa9f578c5e477b2c25cfa404f2b7a (from https://pypi.org/simple/cartopy/) (requires-python:>=3.7). Command errored out with exit status 1: /usr/bin/python3 /usr/local/lib/python3.7/dist-packages/pip/_vendor/pep517/in_process/_in_process.py get_requires_for_build_wheel /tmp/tmpr8agqmvd Check the logs for full command output.

# %% [markdown]
# Import stuff

# %%
from matplotlib import pyplot as plt
from netCDF4 import num2date
import numpy as np
import pydsm.relab as relab
import numpy.matlib
import pandas as pd
import xarray as xr
import zarr
import gcsfs
import pickle
import cftime
import cartopy.crs as ccrs
import dask as da
from eofs.xarray import Eof
from sys import getsizeof
from IPython.display import HTML, display
import time

xr.set_options(display_style='html')
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina' 
from psutil import virtual_memory
ram_gb = virtual_memory().total / 1e9
print('runtime has {:.1f} gigabytes of available RAM\n'.format(ram_gb))

#code for pretty progress bars
def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 100%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))
# Out:
# runtime has 27.3 gigabytes of available RAM

# %%
lon_out=np.arange(1,359,2)
lat_out=np.arange(-89,89,2)
lons_sub, lats_sub = np.meshgrid(lon_out,lat_out)

# %% [markdown]
# Activate Google Drive to store arrays

# %%
if authdrive:
  from google.colab import drive
  drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
plt.rcParams['figure.figsize'] = 12, 6

# %% [markdown]
# ## Browse Catalog
#
# The data catatalog is stored as a CSV file. Here we read it with Pandas.

# %%
df = pd.read_csv('https://storage.googleapis.com/cmip6/cmip6-zarr-consolidated-stores.csv', low_memory=False)

# %% [markdown]
# Variables and experiments in database

# %%
vars=df.variable_id.unique()
vars.sort()
expts_full=df.experiment_id.unique()
expts_full.sort()

flds_full=df.variable_id.unique()
flds_full.sort()

# %%
df[(df["experiment_id"] == 'ssp585-bgc') & (df["variable_id"]=='fgco2')]
# Out:
#        activity_id institution_id      source_id experiment_id member_id  \
# 241987       C4MIP   CNRM-CERFACS    CNRM-ESM2-1    ssp585-bgc  r1i1p1f2
# 409547       C4MIP          MIROC     MIROC-ES2L    ssp585-bgc  r1i1p1f2
# 464151       C4MIP          MIROC     MIROC-ES2L    ssp585-bgc  r1i1p1f2
# 497096       C4MIP          CSIRO  ACCESS-ESM1-5    ssp585-bgc  r1i1p1f1
#
#        table_id variable_id grid_label  \
# 241987     Omon       fgco2         gn
# 409547     Omon       fgco2         gn
# 464151     Omon       fgco2        gr1
# 497096     Omon       fgco2         gn
#
#                                                    zstore  dcpp_init_year  \
# 241987  gs://cmip6/CMIP6/C4MIP/CNRM-CERFACS/CNRM-ESM2-...             NaN
# 409547  gs://cmip6/CMIP6/C4MIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 464151  gs://cmip6/CMIP6/C4MIP/MIROC/MIROC-ES2L/ssp585...             NaN
# 497096  gs://cmip6/CMIP6/C4MIP/CSIRO/ACCESS-ESM1-5/ssp...             NaN
#
#          version
# 241987  20190711
# 409547  20200124
# 464151  20200731
# 497096  20201016

# %% [markdown]
# Make dataframe for each experiment type and each field

# %%
df_all1=[]
for i, row in enumerate(expts):
  df_ta1=[]
  for j,fld in enumerate(flds):
    tmp = df.query("activity_id=='"+dbe[i]+"' & table_id == 'Amon' & variable_id == '"+fld+"' & experiment_id == '"+expts[i]+"'")
    df_ta1.append(tmp)
  df_all1.append(df_ta1)

# %% [markdown]
# Isolate unique models which have completed 4xco2

# %%
mdls1=df_all1[0][0].source_id.unique()
mdls1.sort()
mdls1
# Out:
# array(['ACCESS-CM2', 'ACCESS-ESM1-5', 'AWI-CM-1-1-MR', 'AWI-ESM-1-1-LR',
#        'BCC-CSM2-MR', 'BCC-ESM1', 'CAMS-CSM1-0', 'CAS-ESM2-0', 'CESM2',
#        'CESM2-FV2', 'CESM2-WACCM', 'CESM2-WACCM-FV2', 'CIESM',
#        'CMCC-CM2-HR4', 'CMCC-CM2-SR5', 'CMCC-ESM2', 'CNRM-CM6-1',
#        'CNRM-CM6-1-HR', 'CNRM-ESM2-1', 'CanESM5', 'CanESM5-CanOE',
#        'E3SM-1-0', 'EC-Earth3', 'EC-Earth3-AerChem', 'EC-Earth3-CC',
#        'EC-Earth3-Veg', 'FGOALS-f3-L', 'FGOALS-g3', 'FIO-ESM-2-0',
#        'GFDL-CM4', 'GFDL-ESM4', 'GISS-E2-1-G', 'GISS-E2-1-H',
#        'GISS-E2-2-G', 'GISS-E2-2-H', 'HadGEM3-GC31-LL', 'HadGEM3-GC31-MM',
#        'ICON-ESM-LR', 'IITM-ESM', 'INM-CM4-8', 'INM-CM5-0',
#        'IPSL-CM5A2-INCA', 'IPSL-CM6A-LR', 'KACE-1-0-G', 'KIOST-ESM',
#        'MCM-UA-1-0', 'MIROC-ES2L', 'MIROC6', 'MPI-ESM-1-2-HAM',
#        'MPI-ESM1-2-HR', 'MPI-ESM1-2-LR', 'MRI-ESM2-0', 'NESM3', 'NorCPM1',
#        'NorESM2-LM', 'NorESM2-MM', 'SAM0-UNICON', 'TaiESM1',
#        'UKESM1-0-LL'], dtype=object)

# %% [markdown]
# Make some empty dataframes to store concise list

# %%
cnames=df_all1[0][0].columns
df_all=[]
for i, exp in enumerate(expts):
  tmp=[]
  for j,fld  in enumerate(flds):
    tmp.append(pd.DataFrame(columns=cnames))
  df_all.append(tmp)

# %% [markdown]
# Now get 1 ensemble member for each model, if it exists, for each experiment.  Only add to dataframe df_ta if we have a full set of experiments

# %%
mdls=[]
n=0
for j, mdl in enumerate(mdls1):
    tmpdf=[]
    nruns=[]
    for i, ext in enumerate(expts):
        #find first variable for expt/model
        for j, fld in enumerate(flds):
          tmp=df_all1[i][j].query("source_id=='"+mdl+"'")
          nruns.append(tmp.shape[0])
    #is there at least 1 run per experiment,with all fields?
    if min(nruns)>=1:
      #point to the entry for 1st run, first variable for each expt
      for i, ext in enumerate(expts):
        mmb=df_all1[i][0]['member_id'].values[0]
        for j, fld in enumerate(flds):
          tt = df_all1[i][j].query("source_id=='"+mdl+"' & table_id == 'Amon'")
          df_all[i][j].loc[n]=tt.values[0]
      #add model to final list
      mdls.append(mdl)
      n=n+1

# %%
pickle.dump(mdls, open( "/content/drive/MyDrive/colab_4xco2/mdls.pkl", "wb" ) )

# %%
df_all[1][2].loc(1)

# %% [markdown]
# ## Load Data
#
# Load Google file system

# %%
# load Google cloud storage
gcs = gcsfs.GCSFileSystem(token='anon')

# %% [markdown]
# Loop through zstore links, use zarr to open

# %%
nm=len(mdls)
nf=len(flds)
ne=len(expts)

# %%
df_all[4][0]
# Out:
#     activity_id       institution_id        source_id experiment_id  \
# 0   ScenarioMIP         CSIRO-ARCCSS       ACCESS-CM2        ssp126
# 1   ScenarioMIP                  AWI    AWI-CM-1-1-MR        ssp126
# 2   ScenarioMIP                  BCC      BCC-CSM2-MR        ssp126
# 3   ScenarioMIP                 CAMS      CAMS-CSM1-0        ssp126
# 4   ScenarioMIP                 NCAR            CESM2        ssp126
# 5   ScenarioMIP                 NCAR      CESM2-WACCM        ssp126
# 6   ScenarioMIP                  THU            CIESM        ssp126
# 7   ScenarioMIP                 CMCC     CMCC-CM2-SR5        ssp126
# 8   ScenarioMIP         CNRM-CERFACS       CNRM-CM6-1        ssp126
# 9   ScenarioMIP         CNRM-CERFACS    CNRM-CM6-1-HR        ssp126
# 10  ScenarioMIP         CNRM-CERFACS      CNRM-ESM2-1        ssp126
# 11  ScenarioMIP                CCCma          CanESM5        ssp126
# 12  ScenarioMIP  EC-Earth-Consortium        EC-Earth3        ssp126
# 13  ScenarioMIP                  CAS      FGOALS-f3-L        ssp126
# 14  ScenarioMIP                  CAS        FGOALS-g3        ssp126
# 15  ScenarioMIP             FIO-QLNM      FIO-ESM-2-0        ssp126
# 16  ScenarioMIP            NOAA-GFDL        GFDL-ESM4        ssp126
# 17  ScenarioMIP            NASA-GISS      GISS-E2-1-G        ssp126
# 18  ScenarioMIP                 MOHC  HadGEM3-GC31-LL        ssp126
# 19  ScenarioMIP                 MOHC  HadGEM3-GC31-MM        ssp126
# 20  ScenarioMIP            CCCR-IITM         IITM-ESM        ssp126
# 21  ScenarioMIP                  INM        INM-CM4-8        ssp126
# 22  ScenarioMIP                  INM        INM-CM5-0        ssp126
# 23  ScenarioMIP                 IPSL     IPSL-CM6A-LR        ssp126
# 24  ScenarioMIP             NIMS-KMA       KACE-1-0-G        ssp126
# 25  ScenarioMIP                MIROC       MIROC-ES2L        ssp126
# 26  ScenarioMIP                MIROC           MIROC6        ssp126
# 27  ScenarioMIP                 DKRZ    MPI-ESM1-2-HR        ssp126
# 28  ScenarioMIP                MPI-M    MPI-ESM1-2-LR        ssp126
# 29  ScenarioMIP                  MRI       MRI-ESM2-0        ssp126
# 30  ScenarioMIP                NUIST            NESM3        ssp126
# 31  ScenarioMIP                  NCC       NorESM2-MM        ssp126
# 32  ScenarioMIP              AS-RCEC          TaiESM1        ssp126
# 33  ScenarioMIP                 MOHC      UKESM1-0-LL        ssp126
#
#     member_id table_id variable_id grid_label  \
# 0    r2i1p1f1     Amon         tas         gn
# 1    r1i1p1f1     Amon         tas         gn
# 2    r1i1p1f1     Amon         tas         gn
# 3    r1i1p1f1     Amon         tas         gn
# 4   r10i1p1f1     Amon         tas         gn
# 5    r1i1p1f1     Amon         tas         gn
# 6    r1i1p1f1     Amon         tas         gr
# 7    r1i1p1f1     Amon         tas         gn
# 8    r1i1p1f2     Amon         tas         gr
# 9    r1i1p1f2     Amon         tas         gr
# 10   r1i1p1f2     Amon         tas         gr
# 11   r6i1p2f1     Amon         tas         gn
# 12   r6i1p1f1     Amon         tas         gr
# 13   r1i1p1f1     Amon         tas         gr
# 14   r2i1p1f1     Amon         tas         gn
# 15   r3i1p1f1     Amon         tas         gn
# 16   r1i1p1f1     Amon         tas        gr1
# 17   r1i1p3f1     Amon         tas         gn
# 18   r1i1p1f3     Amon         tas         gn
# 19   r1i1p1f3     Amon         tas         gn
# 20   r1i1p1f1     Amon         tas         gn
# 21   r1i1p1f1     Amon         tas        gr1
# 22   r1i1p1f1     Amon         tas        gr1
# 23   r2i1p1f1     Amon         tas         gr
# 24   r1i1p1f1     Amon         tas         gr
# 25   r1i1p1f2     Amon         tas         gn
# 26   r1i1p1f1     Amon         tas         gn
# 27   r1i1p1f1     Amon         tas         gn
# 28   r8i1p1f1     Amon         tas         gn
# 29   r1i1p1f1     Amon         tas         gn
# 30   r1i1p1f1     Amon         tas         gn
# 31   r1i1p1f1     Amon         tas         gn
# 32   r1i1p1f1     Amon         tas         gn
# 33   r1i1p1f2     Amon         tas         gn
#
#                                                zstore dcpp_init_year   version
# 0   gs://cmip6/CMIP6/ScenarioMIP/CSIRO-ARCCSS/ACCE...            NaN  20200303
# 1   gs://cmip6/CMIP6/ScenarioMIP/AWI/AWI-CM-1-1-MR...            NaN  20190529
# 2   gs://cmip6/CMIP6/ScenarioMIP/BCC/BCC-CSM2-MR/s...            NaN  20190314
# 3   gs://cmip6/CMIP6/ScenarioMIP/CAMS/CAMS-CSM1-0/...            NaN  20190708
# 4   gs://cmip6/CMIP6/ScenarioMIP/NCAR/CESM2/ssp126...            NaN  20200528
# 5   gs://cmip6/CMIP6/ScenarioMIP/NCAR/CESM2-WACCM/...            NaN  20210211
# 6   gs://cmip6/CMIP6/ScenarioMIP/THU/CIESM/ssp126/...            NaN  20200417
# 7   gs://cmip6/CMIP6/ScenarioMIP/CMCC/CMCC-CM2-SR5...            NaN  20200717
# 8   gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...            NaN  20190219
# 9   gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...            NaN  20200127
# 10  gs://cmip6/CMIP6/ScenarioMIP/CNRM-CERFACS/CNRM...            NaN  20190328
# 11  gs://cmip6/CMIP6/ScenarioMIP/CCCma/CanESM5/ssp...            NaN  20190429
# 12  gs://cmip6/CMIP6/ScenarioMIP/EC-Earth-Consorti...            NaN  20200201
# 13  gs://cmip6/CMIP6/ScenarioMIP/CAS/FGOALS-f3-L/s...            NaN  20191013
# 14  gs://cmip6/CMIP6/ScenarioMIP/CAS/FGOALS-g3/ssp...            NaN  20200923
# 15  gs://cmip6/CMIP6/ScenarioMIP/FIO-QLNM/FIO-ESM-...            NaN  20191226
# 16  gs://cmip6/CMIP6/ScenarioMIP/NOAA-GFDL/GFDL-ES...            NaN  20180701
# 17  gs://cmip6/CMIP6/ScenarioMIP/NASA-GISS/GISS-E2...            NaN  20200115
# 18  gs://cmip6/CMIP6/ScenarioMIP/MOHC/HadGEM3-GC31...            NaN  20200114
# 19  gs://cmip6/CMIP6/ScenarioMIP/MOHC/HadGEM3-GC31...            NaN  20200515
# 20  gs://cmip6/CMIP6/ScenarioMIP/CCCR-IITM/IITM-ES...            NaN  20201112
# 21  gs://cmip6/CMIP6/ScenarioMIP/INM/INM-CM4-8/ssp...            NaN  20190603
# 22  gs://cmip6/CMIP6/ScenarioMIP/INM/INM-CM5-0/ssp...            NaN  20190619
# 23  gs://cmip6/CMIP6/ScenarioMIP/IPSL/IPSL-CM6A-LR...            NaN  20190410
# 24  gs://cmip6/CMIP6/ScenarioMIP/NIMS-KMA/KACE-1-0...            NaN  20191007
# 25  gs://cmip6/CMIP6/ScenarioMIP/MIROC/MIROC-ES2L/...            NaN  20190823
# 26  gs://cmip6/CMIP6/ScenarioMIP/MIROC/MIROC6/ssp1...            NaN  20190627
# 27  gs://cmip6/CMIP6/ScenarioMIP/DKRZ/MPI-ESM1-2-H...            NaN  20190710
# 28  gs://cmip6/CMIP6/ScenarioMIP/MPI-M/MPI-ESM1-2-...            NaN  20190710
# 29  gs://cmip6/CMIP6/ScenarioMIP/MRI/MRI-ESM2-0/ss...            NaN  20191108
# 30  gs://cmip6/CMIP6/ScenarioMIP/NUIST/NESM3/ssp12...            NaN  20190731
# 31  gs://cmip6/CMIP6/ScenarioMIP/NCC/NorESM2-MM/ss...            NaN  20191108
# 32  gs://cmip6/CMIP6/ScenarioMIP/AS-RCEC/TaiESM1/s...            NaN  20201124
# 33  gs://cmip6/CMIP6/ScenarioMIP/MOHC/UKESM1-0-LL/...            NaN  20190503

# %%
if readdata:
  out = display(progress(0, 1), display_id=True)
  dsall=[]
  for i,df_ta in enumerate(df_all):

    dsm=[]
    for j,df in enumerate(df_ta):
      ds=[]
      print(expts[i]+','+flds[j])
      for index, item in enumerate(df.zstore.values, start=0):
        mapper=gcs.get_mapper(item)
        ds.append(xr.open_zarr(mapper, decode_times=False))
        out.update(progress(index+j*nm+i*nm*nf, ne*nm*nf))
      dsm.append(ds)
    dsall.append(dsm)
# Out:
#         <progress
#             value='815'
#             max='816',
#             style='width: 100%'
#         >
#             815
#         </progress>
# 1pctCO2,tas
# 1pctCO2,rsut
# 1pctCO2,rlut
# 1pctCO2,rsdt
# abrupt-4xCO2,tas
# abrupt-4xCO2,rsut
# abrupt-4xCO2,rlut
# abrupt-4xCO2,rsdt
# piControl,tas
# piControl,rsut
# piControl,rlut
# piControl,rsdt
# historical,tas
# historical,rsut
# historical,rlut
# historical,rsdt
# ssp126,tas
# ssp126,rsut
# ssp126,rlut
# ssp126,rsdt
# ssp585,tas
# ssp585,rsut
# ssp585,rlut
# ssp585,rsdt

# %% [markdown]
# concatenated dataarrays for ts, global mean

# %%
 
if readdata:
  dall=[]
  out = display(progress(0, 1), display_id=True)
  for i,ds in enumerate(dsall,start=0):
    dexp=[]
    for j,dm in enumerate(ds):
      print(expts[i]+','+flds[j])
      for index, dd in enumerate(dm, start=0):
          if 'longitude' in dd.keys():
            dd=dd.rename({'longitude': 'lon','latitude': 'lat'})
          if 'latitude' in dd.coords:
            dd=dd.drop('latitude')  
            dd=dd.drop_dims('latitude')
       
          tmp=dd[flds[j]][:4800,:,:].interp(lon=lon_out,lat=lat_out, kwargs={"fill_value": "extrapolate"})
          if calstrt[i]:
            tmp.coords['time']=pd.date_range('1850-01-01', periods=tmp['time'].values.shape[0],freq='M')
          if tmp['time'].dtype=='float64' or  tmp['time'].dtype=='int64':
            tmp.coords['time']=num2date(tmp['time'].values,tmp['time'].units)
#          if 'historical' in expts[i]:
##            tmpf=dsall[expts.index('ssp585')][j][index][flds[j]].interp(lon=lon_out,lat=lat_out, kwargs={"fill_value": "extrapolate"})
 #           if tmpf['time'].dtype=='float64' or  tmpf['time'].dtype=='int64':
 ##             tmpf.coords['time']=num2date(tmpf['time'].values,tmpf['time'].units)
#            tmp=xr.concat([tmp,tmpf],'time')
#            tmp=tmp.where(tmp['time.year'] < 2021, drop=True)
#          if 'ssp' in expts[i]:
#            tmp=tmp.where(tmp['time.year'] > 2014, drop=True)        
          srm=tmp.groupby('time.year').mean('time')
          if index==0:
            dac=srm
          else:
            dac=xr.concat([dac,srm],'ens',coords='minimal',compat='override')
          out.update(progress(index+j*nm+i*nm*nf, ne*nm*nf))
      dexp.append(dac)
    dall.append(dexp)
# Out:
#         <progress
#             value='815'
#             max='816',
#             style='width: 100%'
#         >
#             815
#         </progress>
# 1pctCO2,tas
# 1pctCO2,rsut
# 1pctCO2,rlut
# 1pctCO2,rsdt
# abrupt-4xCO2,tas
# abrupt-4xCO2,rsut
# abrupt-4xCO2,rlut
# abrupt-4xCO2,rsdt
# piControl,tas
# piControl,rsut
# piControl,rlut
# piControl,rsdt
# historical,tas
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 14
#   **blockwise_kwargs,
# historical,rsut
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 14
#   **blockwise_kwargs,
# historical,rlut
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 14
#   **blockwise_kwargs,
# historical,rsdt
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 14
#   **blockwise_kwargs,
# ssp126,tas
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 11
#   **blockwise_kwargs,
# ssp126,rsut
# ssp126,rlut
# ssp126,rsdt
# ssp585,tas
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 11
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 17
#   **blockwise_kwargs,
# ssp585,rsut
# ssp585,rlut
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 29
#   **blockwise_kwargs,
# ssp585,rsdt

# %%
dall[5][0][0]
# Out:
# <xarray.DataArray 'tas' (year: 287, lat: 89, lon: 179)>
# dask.array<getitem, shape=(287, 89, 179), dtype=float32, chunksize=(1, 89, 179), chunktype=numpy.ndarray>
# Coordinates:
#   * year     (year) int64 2014 2015 2016 2017 2018 ... 2296 2297 2298 2299 2300
#     height   float64 ...
#   * lon      (lon) int64 1 3 5 7 9 11 13 15 ... 343 345 347 349 351 353 355 357
#   * lat      (lat) int64 -89 -87 -85 -83 -81 -79 -77 ... 75 77 79 81 83 85 87

# %% [markdown]
# Find complete runs

# %%
if readdata:
  out = display(progress(0, 1), display_id=True)
  for i,d in enumerate(dall,start=0):
    tmp=xr.merge(d[:])
    tmp.to_netcdf('/content/drive/MyDrive/colab_4xco2/'+expts[i]+'.nc')
    #lat=tmp.tas.lat
    #weights = np.cos(np.deg2rad(lat))
    #weights.name = "weights"
    #tmp_gm=tmp.weighted(weights).mean(dim='lat').mean(dim='lon')
    #tmp_gm.to_netcdf('/content/drive/MyDrive/colab_4xco2/'+expts[i]+'_gm.nc')
    out.update(progress(i,ne))
# Out:
#         <progress
#             value='5'
#             max='6',
#             style='width: 100%'
#         >
#             5
#         </progress>
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,
# /usr/local/lib/python3.7/dist-packages/dask/array/core.py:3908: PerformanceWarning: Increasing number of chunks by factor of 34
#   **blockwise_kwargs,

# %%
  
if readdata:
  out = display(progress(0, 1), display_id=True)
  for i,d in enumerate(dall,start=0):
    tmp=xr.open_dataset('/content/drive/MyDrive/colab_4xco2/'+expts[i]+'.nc')
    lat=tmp.tas.lat
    weights = np.cos(np.deg2rad(lat))
    weights.name = "weights"
    tmp_gm=tmp.weighted(weights).mean(dim='lat').mean(dim='lon')
    tmp_gm.to_netcdf('/content/drive/MyDrive/colab_4xco2/'+expts[i]+'_gm.nc')
    out.update(progress(i,ne))
